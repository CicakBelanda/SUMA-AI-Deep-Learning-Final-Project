# %%
from huggingface_hub import login, create_repo, upload_folder

# 1. LOGIN with token
login(token="hf_this is token lol")   # wajib isi token

# 2. CONFIG
repo_id = "brotoo/BART-NewsSummarizer"
model_folder = "./BART_NewsSummarizer"

# 3. Create repo if not exists
create_repo(repo_id, repo_type="model", private=False, exist_ok=True)

# 4. Upload
upload_folder(
    folder_path=model_folder,
    repo_id=repo_id,
    repo_type="model",
    commit_message="upload fine-tuned model"
)

print("Upload selesai 🚀")
# Out:
# model.safetensors: 100%|██████████| 558M/558M [01:01<00:00, 9.05MB/s]
# Upload selesai 🚀
